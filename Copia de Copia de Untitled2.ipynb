# %%
def biseccion(f, a, b, e):   
  while (b-a>=e):   
    c=(a+b)/2         
    if f(c)==0:  
      return c
    else:
          if f(a)*f(c)>0:   
             a=c   
          else: 
             b=c   
              
    return c

# %%
from sympy import*    
x=Symbol('x')     
f=250-192*x+28*x**2-x**3  
plot (f,(x,0,20))   
r=solve(f)
r
r[0].evalf(5),r[1].evalf(5),r[2].evalf(5)
from math import* 

def f(x): return x*exp(x)-pi 
c=biseccion(f,7,10,0.000001) 
c
# Out:
# 8.5

# %%
 def f(x): return x*exp(x)-pi  
 c=biseccion(f,0,2,0.000001)

# %%
c
# Out:
# 1.0

# %%
from pylab import*
x=arange(0,3.5,0.1)
f=4+x*cos(x+1) 
g=exp(x)*sin(x)
plot(x,f,'b')
plot(x,g,'r')
grid(True)
show()

# %%
def biseccion(f, a, b, e):   
  while (b-a>=e):   
    c=(a+b)/2         
    if f(c)==0:  
      return c
    else:
          if f(a)*f(c)>0:   
             a=c   
          else: 
             b=c   
              
    return c 
from math import* 
def h(x): return exp(x)*sin(x)-4-x*cos(x+1) 
r=biseccion(h,1,1.5,0.000001)
r
# Out:
# 1.25

# %% [markdown]
# Ejemplo.  EJEMPLO.xxxx.Calcule una raíz real de la misma ecuación f(x) = e^x - πx = 0 con el método del punto fijo con otra forma de la ecuación de recurrencia x=g(x).
#
# Para este ejemplo se decide usar la segunda forma:  x = g(x) = ln(πx)
#
#
# Ejemplo. Calcular con Python la segunda raíz de la ecuación:  f(x)=exp(x)-πx  mediante la fórmula de recurrencia:   x=g(x)=ln(πx)

# %%
from math import*
def g(x): return log(pi*x)
x=1.6        #   Valor inicial para la segunda raíz 
x=g(x) 
print(x) 
x=g(x) 
print(x)
x=g(x)
print(x)
x=g(x)
print(x)
x=g(x)
print(x)
# Out:
# 1.6147335150951356
# 1.6238998227759673
# 1.62956044020348
# 1.6330401957141376
# 1.63517331417909

# %% [markdown]
# ## Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/)
# to be rendered by [MathJax](https://www.mathjax.org). Just place the statement
# within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^3$' becomes
# $\sqrt{3x-1}+(1+x)^3.$

# %% [markdown]
#  $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# Newton

# %%
from sympy import*
x=Symbol('x') 
f=x**2
df=diff(f,x)
r=1 #(colocar el valor inicial)
r=r-float(f.subs(x,r))/float(df.subs(x,r))
print(r) 
plot(f,(x,0,3))
# Out:
# 0.5

# %%
from sympy import* 
x=Symbol('x') 
f=exp(x)-pi*x 
plot(f,(x,0,2))

# %%
df=diff(f,x)   #Obtención de f’(x)
r=0.5          #Valor inicial del gráfico
r=r-float(f.subs(x,r))/float(df.subs(x,r))        #float  evalúa la expresión 
r
# Out:
# 0.552198029112459

# %%
r=r-float(f.subs(x,r))/float(df.subs(x,r)) 
print (r)          
r=r-float(f.subs(x,r))/float(df.subs(x,r))
print (r)   
r=r-float(f.subs(x,r))/float(df.subs(x,r)) 
print (r)  
r=r-float(f.subs(x,r))/float(df.subs(x,r))
print (r)        
float(f.subs(x,r))    #  Verificar si f(r) = 0 -1.5192266539886956e-17
# Out:
# 0.5538270366445136
# 0.5538270366445136
# 0.5538270366445136
# 0.5538270366445136
# -1.5192266539886956e-17

# %%
#Finalmente, es necesario verificar que este resultado satisface a la ecuación: 
 
#Si se comienza con  r = 1.5  se puede calcular la otra raíz real: 
f=exp(x)-pi*x 
r=1.5
r=r-float(f.subs(x,r))/float(df.subs(x,r))
print(r)
# Out:
# 1.6721517251769213

# %%
float(f.subs(x,r))
# Out:
# 0.07039085315532465

# %%
#Ejemplo.  Se propone el siguiente modelo para describir la demanda de un producto, en donde x es tiempo en meses:   0.075x d(x) 20x e− 0.075x= Encuentre el valor de x para el cual la demanda alcanza por primera vez el valor de 80 unidades. Use el método de Newton para los cálculos. Elija el valor inicial del gráfico y muestre los valores intermedios.  
 
#La ecuación a resolver es:   0.075x f(x) 20x e-0.075x-80= 0 

from sympy import*
x=Symbol('x')
f=20*x*exp(-0.075*x)-80
plot(f,(x,0,50))
r=5
df=diff(f,x)
r=r-float(f.subs(x,r))/float(df.subs(x,r))
r
r=r-float(f.subs(x,r))/float(df.subs(x,r))
r=r-float(f.subs(x,r))/float(df.subs(x,r))
r=r-float(f.subs(x,r))/float(df.subs(x,r))

# %%
r
# Out:
# 6.525363029068741
